# %%
Geospatial_data_analysis.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1072/2723331096.py in <cell line: 0>()
# ----> 1 Geospatial_data_analysis.ipynb
#
# NameError: name 'Geospatial_data_analysis' is not defined
